# %% [markdown]
# # **Project Name**    - UBER SUPPLY DEMAND GAP

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member  -**  P.Jayagopi

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This project analyzes the Uber trip request dataset, which contains detailed records of ride requests, including request IDs, pickup points (Airport or City), driver IDs, trip statuses (Trip Completed, Cancelled, No Cars Available), request timestamps, and drop timestamps. The primary objective is to extract actionable insights to enhance Uber's operational efficiency and customer experience.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The dataset comprises Uber trip request records with key attributes including request ID, pickup point (Airport or City), driver ID, trip status (such as Trip Completed, Cancelled, No Cars Available), request timestamp, and drop timestamp. The primary goal is to analyze this dataset to extract meaningful insights and patterns that can help improve Uber's operational efficiency and customer experience.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# 1. Identify Peak Demand Periods and Locations
#
# 2. Determine the busiest hours and days for Uber trip requests.
#
# 3. Analyze demand differences between pickup points (Airport vs. City).
#
# 4. Analyze Trip Status and Service Availability
#
# 5. Calculate cancellation rates and instances of no cars available.
#
# 6. Explore how these rates vary by time of day and pickup location.
#
# 7. Evaluate Driver Efficiency and Trip Duration
#
# 8. Measure average trip duration and variability across drivers and locations.
#
# 9. Assess driver performance in completing trips successfully.
#
# 10. Detect Supply-Demand Imbalances
#
# 11. Identify specific time windows or locations with high demand but insufficient supply.
#
# 12. Understand patterns leading to cancellations or unavailability of cars.
#
# 13. Provide Recommendations
#
# 14. Suggest strategies to optimize driver allocation and reduce cancellations.
#
# 15. Propose improvements to enhance customer satisfaction and service reliability.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib as plt

# %% [markdown]
# ### Dataset Loading

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("Uber Request Data.csv")

# Show first few rows
print(df.head())
# Out:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# 3        2532      Airport        1.0  Trip Completed      12/7/2016 21:08
# 4        3112         City        1.0  Trip Completed  13-07-2016 08:33:16
#
#         Drop timestamp
# 0      11/7/2016 13:00
# 1      11/7/2016 18:47
# 2       12/7/2016 9:58
# 3      12/7/2016 22:03
# 4  13-07-2016 09:25:47

# %% [markdown]
# ### Dataset First View

# %%
# Step 1: Import necessary libraries
import pandas as pd

# Step 2: Load the dataset
file_path = "Uber Request Data.csv"  # Ensure this CSV file is in the same directory as your script
df = pd.read_csv(file_path)

# Step 3: Display basic dataset information
print(" Dataset Info:")
print(df.info())  # Shows data types and missing values

print("\n First 5 Rows of the Dataset:")
print(df.head())  # Shows the top 5 rows

print("\n Summary Statistics:")
print(df.describe(include='all'))  # Gives a statistical summary for all columns
# Out:
#  Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request id         6745 non-null   int64
#  1   Pickup point       6745 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             6745 non-null   object
#  4   Request timestamp  6745 non-null   object
#  5   Drop timestamp     2831 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 316.3+ KB
# None
#
#  First 5 Rows of the Dataset:
#    Request id Pickup point  Driver id          Status    Request timestamp  \
# 0         619      Airport        1.0  Trip Completed      11/7/2016 11:51
# 1         867      Airport        1.0  Trip Completed      11/7/2016 17:57
# 2        1807         City        1.0  Trip Completed       12/7/2016 9:17
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
import pandas as pd

# Load the dataset
file_path = "Uber Request Data.csv"
df = pd.read_csv(file_path)

# Count rows and columns
num_rows, num_columns = df.shape

# Print the results
print(f"Total Rows: {num_rows}")
print(f"Total Columns: {num_columns}")
# Out:
# Total Rows: 6745
# Total Columns: 6

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
import pandas as pd

# Load the dataset
file_path = "Uber Request Data.csv"
df = pd.read_csv(file_path)

# Display basic information
print(" Dataset Info:")
print(df.info())  # Includes column names, non-null counts, and data types

print("\n Column-wise Summary Statistics:")
print(df.describe(include='all'))  # Summary for numeric and categorical columns

print("\n Column Names:")
print(df.columns.tolist())  # List all column names

print("\n Missing Values in Each Column:")
print(df.isnull().sum())  # Count of missing values per column
# Out:
#  Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6745 entries, 0 to 6744
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Request id         6745 non-null   int64
#  1   Pickup point       6745 non-null   object
#  2   Driver id          4095 non-null   float64
#  3   Status             6745 non-null   object
#  4   Request timestamp  6745 non-null   object
#  5   Drop timestamp     2831 non-null   object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 316.3+ KB
# None
#
#  Column-wise Summary Statistics:
#          Request id Pickup point    Driver id          Status  \
# count   6745.000000         6745  4095.000000            6745
# unique          NaN            2          NaN               3
# top             NaN         City          NaN  Trip Completed
# freq            NaN         3507          NaN            2831
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
import pandas as pd

# Load the dataset
file_path = "Uber Request Data.csv"
df = pd.read_csv(file_path)

# Find duplicate rows
duplicates = df[df.duplicated()]

# Print the number of duplicate rows
print(f"🔁 Number of duplicate rows: {duplicates.shape[0]}")

# Optional: Display the duplicate rows
if not duplicates.empty:
    print("\n Duplicate Rows:")
    print(duplicates)
else:
    print("No duplicate rows found.")
# Out:
# 🔁 Number of duplicate rows: 0
# No duplicate rows found.

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
import pandas as pd

# Load the dataset
file_path = "Uber Request Data.csv"
df = pd.read_csv(file_path)

# Check for missing/null values
print("Missing/Null Values Summary:\n")
missing_values = df.isnull().sum()

# Display only columns with missing values
missing_values = missing_values[missing_values > 0]
if not missing_values.empty:
    print(missing_values)
else:
    print(" No missing or null values found in the dataset.")

# Optional: Show percentage of missing data
print("\n Percentage of Missing Data per Column:")
percent_missing = (df.isnull().mean() * 100).round(2)
print(percent_missing[percent_missing > 0])
# Out:
# Missing/Null Values Summary:
#
# Driver id         2650
# Drop timestamp    3914
# dtype: int64
#
#  Percentage of Missing Data per Column:
# Driver id         39.29
# Drop timestamp    58.03
# dtype: float64

# %%
# Visualizing the missing values
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno

# Load the dataset
file_path = "Uber Request Data.csv"
df = pd.read_csv(file_path)

# Show missing value summary
print(" Missing Values Summary:")
missing_counts = df.isnull().sum()
print(missing_counts[missing_counts > 0])

# Optional: Percentage of missing data
print("\n  Missing Data Percentage:")
missing_percent = (df.isnull().mean() * 100).round(2)
print(missing_percent[missing_percent > 0])

#  Visualization using seaborn heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.title("Heatmap of Missing Values")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.show()

#  Visualization using missingno matrix
msno.matrix(df)
plt.title("Missing Value Matrix")
plt.show()

#  Missing value bar chart
msno.bar(df)
plt.title("Missing Value Count per Column")
plt.show()
# Out:
#  Missing Values Summary:
# Driver id         2650
# Drop timestamp    3914
# dtype: int64
#
#   Missing Data Percentage:
# Driver id         39.29
# Drop timestamp    58.03
# dtype: float64

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# This dataset contains information about ride requests made through Uber within a specific timeframe. Each record (row) represents a single ride request and includes details about:
# request timings,Pickup locations,Trip statuses (Completed, Cancelled, or No Cars Available).

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
import pandas as pd

# Load the dataset
file_path = "Uber Request Data.csv"  
df = pd.read_csv(file_path)

# Display the column names
print("Columns in the dataset:")
print(df.columns.tolist())

# %%
# Dataset Describe
import pandas as pd

# Load the dataset
file_path = "Uber Request Data.csv"
df = pd.read_csv(file_path)

# Display first few rows (optional for preview)
print("First 5 rows of the dataset:")
print(df.head())

# General info about dataset
print("\nDataset Info:")
print(df.info())

# Description of numerical columns
print("\nStatistical Summary (Numerical Columns):")
print(df.describe())

# Description of non-numerical (categorical/text) columns
print("\nSummary of Categorical Columns:")
print(df.describe(include='object'))

# %% [markdown]
# ### Variables Description

# %% [markdown]
# | **Variable Name**   | **Data Type**                             | **Description**                                                                                                                |
# | ------------------- | ----------------------------------------- | ------------------------------------------------------------------------------------------------------------------------------ |
# | `Request id`        | Integer (int64)                           | A unique identifier for each ride request.                                                                                     |
# | `Pickup point`      | Categorical (object)                      | The location from which the ride was requested. Typically "City" or "Airport".                                                 |
# | `Driver id`         | Float (float64)                           | The ID of the driver who accepted the trip. May be **NaN** if no driver was assigned.                                          |
# | `Status`            | Categorical (object)                      | The final status of the ride request. Possible values include:<br>• `Trip Completed`<br>• `Cancelled`<br>• `No Cars Available` |
# | `Request timestamp` | String/Object (needs datetime conversion) | The date and time when the user made the ride request. Needs conversion to `datetime`.                                         |
# | `Drop timestamp`    | String/Object (nullable)                  | The date and time when the trip ended. **Null** if trip wasn’t completed.                                                      |

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
import pandas as pd

# Load the dataset
file_path = "Uber Request Data.csv"
df = pd.read_csv(file_path)

# Loop through each column and print unique values
print("Unique values in each column:\n")
for column in df.columns:
    unique_vals = df[column].unique()
    print(f"{column} ({len(unique_vals)} unique values):")
    print(unique_vals[:10])  # Show only first 10 unique values for brevity
    print("-" * 50)

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
import pandas as pd

# Step 1: Load the dataset
df = pd.read_csv("Uber Request Data.csv")

# Step 2: Rename columns for consistency (remove spaces and lowercase)
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# Step 3: Convert timestamps to datetime format
df['request_timestamp'] = pd.to_datetime(df['request_timestamp'], dayfirst=True, errors='coerce')
df['drop_timestamp'] = pd.to_datetime(df['drop_timestamp'], dayfirst=True, errors='coerce')

# Step 4: Check and handle missing values
missing_summary = df.isnull().sum()
print("Missing values per column:\n", missing_summary)

# Step 5: Drop duplicate rows if any
df.drop_duplicates(inplace=True)

# Step 6: Create additional time-based features
df['request_hour'] = df['request_timestamp'].dt.hour
df['request_day'] = df['request_timestamp'].dt.date

# Step 7: Optional – filter out rows with invalid timestamps if needed
df = df[df['request_timestamp'].notnull()]

# Final check
print("\nCleaned dataset preview:")
print(df.head())

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Data Manipulations Performed :Cleaned column Names,Converted TimeStamps,Handled Missing Values,Extracted Time Features,Removed duplicates.The key insights includes :Data Manipulations Performed(trip completed,cancelled,No cars availble),Peak Demand Hours(Between 5AM to 10AM and 5PM to 9PM),High Cancellation During Morning Hours is in between 5AM to 9AM due to traffic,No cars were availble from Airport after 9PM.These are the major and manipulations and insights that are found from the dataset.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("clean data.csv")

# Display the first few rows to understand the structure
print(df.head())

# Check the column names
print(df.columns)

# Replace 'CategoryColumn' and 'ValueColumn' with actual column names from your CSV
category_column = 'Pickup Point,Status' 
value_column = 'Request id'      

# Ensure the value column is numeric
df[value_column] = pd.to_numeric(df[value_column], errors='coerce')

# Handle missing values if necessary
df[value_column].fillna(0, inplace=True)

# Group data (if necessary) and create bar chart
bar_data = df.groupby(category_column)[value_column].sum().sort_values(ascending=False)

# Plotting the bar chart
bar_data.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title(f'{value_column} by {category_column}')
plt.xlabel(category_column)
plt.ylabel(value_column)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, I have pick the BAR CHART,which is common and  prrovide better understanding of the data with the axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By the help of the BAR CHART some insights are found they are as follow: Sum of the Request id ,Pickup point location and their Status

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the chart will be useful in  the business analysis. The insight  will be impacting on the busniess fro the UBER fro improving  and developing their business

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("clean data.csv")

# Preview the first few rows
print(df.head())

# Replace 'CategoryColumn' and 'ValueColumn' with actual column names
category_column ='Pickup location ' 
value_column = ' Driver id'      

# Aggregate the data
pie_data = df.groupby(category_column)[value_column].sum()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(pie_data, labels=pie_data.index, autopct='%1.1f%%', startangle=140)
plt.title(f'{value_column} Distribution by {category_column}')
plt.axis('equal')  # Equal aspect ratio ensures pie is drawn as a circle
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# PIE CHART for circular and better understandig of large dataand to simply the data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows the overall represtation of the data on the different fields like Airport, City  with thier  status option

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights from the this particular helps the organizations improvement and able to analysis in an simpler manner

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("clean data.csv")

# Count the number of requests for each status
status_counts = df['Status'].value_counts()

# Plot bar chart
plt.figure(figsize=(8, 6))
status_counts.plot(kind='bar', color='blue')
plt.title('Trip Status Count')
plt.xlabel('Trip Status')
plt.ylabel('Number of Requests')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart gives the detailed description on the data used in the dataset by the visualization  tool

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are includes by the following chart are: status and the completion of the service and the code

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Only the False insights from the chart or the dataset will lead to negative impact on the company business, but this chart will not gives the negative  statement

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load data
df = pd.read_csv("clean data.csv")

# Pivot data: counts of each Status by Pickup point
pivot_df = df.groupby(['Pickup point', 'Status']).size().unstack(fill_value=0)

# Categories (trip statuses)
categories = list(pivot_df.columns)
num_vars = len(categories)

# Angle for each axis in the plot
angles = np.linspace(0, 2 * np.pi, num_vars, endpoint=False).tolist()
angles += angles[:1]  # repeat first angle to close the circle

# Prepare the radar plot
plt.figure(figsize=(8, 8))
ax = plt.subplot(111, polar=True)

# Plot each Pickup point
for index, row in pivot_df.iterrows():
    values = row.tolist()
    values += values[:1]  # repeat the first value to close the circle
    ax.plot(angles, values, label=index)
    ax.fill(angles, values, alpha=0.25)

# Add labels
ax.set_theta_offset(np.pi / 2)
ax.set_theta_direction(-1)
ax.set_thetagrids(np.degrees(angles[:-1]), categories)
ax.set_title("Trip Status Comparison by Pickup Point", y=1.1)
ax.legend(loc='upper right', bbox_to_anchor=(1.3, 1.1))
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The observation and the clearity of this RADAR chart will be gives valueable impact on the dataset

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The Representation of the chart with dataset will create the positive impact on the business analysis

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# There won't be any  negative impact on the  data

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load data
df = pd.read_csv("clean data.csv")

# Filter only 'Trip Completed' statuses
completed_df = df[df['Status'] == 'Trip Completed']

# Count total requests and completed trips by Pickup point
total_requests = df['Pickup point'].value_counts()
completed_requests = completed_df['Pickup point'].value_counts()

# Align indices
pickup_points = total_requests.index
total = total_requests.values
completed = completed_requests.reindex(pickup_points, fill_value=0).values

# Plot
fig, ax1 = plt.subplots(figsize=(8, 6))

# Bar chart for total requests
ax1.bar(pickup_points, total, color='lightgray', label='Total Requests')
ax1.set_ylabel('Total Requests')
ax1.set_xlabel('Pickup Point')

# Line chart for completed trips
ax2 = ax1.twinx()
ax2.plot(pickup_points, completed, color='blue', marker='o', label='Completed Trips')
ax2.set_ylabel('Completed Trips')

# Title and legend
plt.title('Combo Chart: Total Requests vs Completed Trips by Pickup Point')
fig.legend(loc='upper right', bbox_to_anchor=(1, 1), bbox_transform=ax1.transAxes)

plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart shows:
#
# How many total trip requests each pickup point received (bars)
#
# How many of those were completed (line)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# 1. City vs Airport Demand
# City had more total ride requests compared to Airport.
#
# This indicates higher passenger activity or demand from within the city limits.
#
# Possibly due to people commuting to work, shopping, or other daily needs.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight is mixed, but leans negative overall because:
#
# There is unmet demand, especially at the Airport.
#
# Operational inefficiencies are clearly visible, which means there's room for improvement.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("clean data.csv")

# Rename the timestamp column for easier handling
df.rename(columns={'Request timestamp.3': 'Request Timestamp'}, inplace=True)

# Convert timestamp to datetime format
df['Request Timestamp'] = pd.to_datetime(df['Request Timestamp'], errors='coerce')

# Drop rows with invalid/missing timestamps
df.dropna(subset=['Request Timestamp'], inplace=True)

# Extract hour from the timestamp
df['Hour'] = df['Request Timestamp'].dt.hour

# Group by hour and trip status
hourly_status = df.groupby(['Hour', 'Status']).size().unstack(fill_value=0)

# Plot area chart
plt.figure(figsize=(12, 6))
hourly_status.plot.area(alpha=0.7, colormap='tab20')
plt.title('Trip Status Distribution by Hour of the Day')
plt.xlabel('Hour of the Day')
plt.ylabel('Number of Requests')
plt.xticks(range(0, 24))
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Morning Peak (7 AM – 10 AM):
#
# High demand observed.
#
# Large area under "No Cars Available" and "Cancelled" — indicating significant unmet demand during morning commute hours.
#
# Many users are requesting rides but aren't getting matched with drivers.
#
# Evening Peak (5 PM – 9 PM):
#
# Another spike in demand.
#
# Again, a high proportion of "No Cars Available", but more "Trip Completed" compared to morning.
#
# Off-Peak Hours (Midnight – 5 AM):
#
# Very low overall activity.
#
# Minimal trips, mostly quiet hours.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Increase driver availability during peak hours (7–10 AM and 5–9 PM).
#
# Provide incentives or bonuses for drivers accepting rides at busy times.
#
# Improve matching algorithms to reduce cancellation and waiting time.
#
# Communicate demand insights to drivers to better manage supply.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Negative Revenue Impact:
#
# High number of unfulfilled ride requests during peak hours leads to loss of potential income.
#
# Users may switch to competitors due to poor availability, affecting customer retention.
#
# Driver Shortage Detection:
#
# Clear sign of supply-demand mismatch in early mornings and evenings.
#
# Opportunity to improve driver incentives or shift planning during peak hours.
#
# Operational Bottlenecks:
#
# High cancellations could be due to long wait times, traffic congestion, or location-based inefficiencies.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
import pandas as pd

# Load the dataset to inspect the columns
file_path = "/mnt/data/clean data.csv"
df = pd.read_csv(file_path)

# Show the first few rows and column names
df.head(), df.columns.tolist()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This is a code to represent the data set column with the proper data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insights are the type of column anda the cleaning process for the data in the address off the location

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 9 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
df = pd.read_csv("clean data.csv")

# Preview the first few rows
print(df.head())

# Replace 'CategoryColumn' and 'ValueColumn' with actual column names
category_column ='Pickup location ' 
value_column = ' Status'      

# Aggregate the data
pie_data = df.groupby(category_column)[value_column].sum()

# Create the pie chart
plt.figure(figsize=(8, 8))
plt.pie(pie_data, labels=pie_data.index, autopct='%1.1f%%', startangle=140)
plt.title(f'{value_column} Distribution by {category_column}')
plt.axis('equal')  # Equal aspect ratio ensures pie is drawn as a circle
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# PIE CHART for circular and better understandig of large dataand to simply the data with the location and Status of the data

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This chart shows the overall represtation of the data on the different fields like Airport, City  with thier  status option as Comppleted, NOt completed and
# No cars availble

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# These insights from the this particular helps the organizations improvement and able to analysis in an simpler manner. Pie chart is a circular sturcture chart that can be used fro the represting ther bigger data

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 10 visualization code
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
df = pd.read_csv("clean data.csv")

# Display the first few rows to understand the structure
print(df.head())

# Check the column names
print(df.columns)

# Replace 'CategoryColumn' and 'ValueColumn' with actual column names from your CSV
category_column = 'Status'  
value_column = 'Request id'       

# Ensure the value column is numeric
df[value_column] = pd.to_numeric(df[value_column], errors='coerce')

# Handle missing values if necessary
df[value_column].fillna(0, inplace=True)

# Group data (if necessary) and create bar chart
bar_data = df.groupby(category_column)[value_column].sum().sort_values(ascending=False)

# Plotting the bar chart
bar_data.plot(kind='bar', figsize=(10, 6), color='skyblue')
plt.title(f'{value_column} by {category_column}')
plt.xlabel(category_column)
plt.ylabel(value_column)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Here, I have pick the POLAR CHART,which is common and  prrovide better understanding of the data with the axis.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# By the help of the POLAR CHART some insights are found they are as follow: Sum of the Request id ,Pickup point location and their Status

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights from the chart will be useful in  the business analysis. The insight  will be impacting on the busniess fro the UBER fro improving  and developing their business

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?

# %% [markdown]
# The primary business objective is to optimize Uber’s ride-hailing operations by minimizing service gaps, reducing cancellations, and improving customer satisfaction through data-driven insights from the trip request datase
#
# The key Aspects of the Business Goal as follows :
#
# (i) Reduce Lost Revenue Opportunities:
#          By identifying when and where ride requests are most likely to be cancelled or go unfulfilled (e.g., due to "No Cars Available"), Uber can deploy more drivers to high-demand areas and times, minimizing missed trips and increasing completed rides.
#
# (ii) Enhance Customer Experience:
#          Analyzing trip data helps Uber understand and reduce customer wait times, cancellations, and service failures, resulting in a smoother, more reliable experience that encourages customer loyalty.
#
# (iii) Optimize Driver Utilization:
#          Insights from the data allow Uber to better match drivers with demand, increasing driver earnings and satisfaction by reducing idle time and maximizing the number of trips per shift.
#
# (iv) Support Strategic Planning:
#          The analysis informs business strategies such as targeted promotions, dynamic pricing, and incentive programs, all aimed at improving market share and profitability.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Overall Conclusion for the Uber Trip Request Dataset. The analysis of the provided Uber trip request dataset reveals several important insights into Uber’s operational efficiency and customer service performance during the observed period.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
